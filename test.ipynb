# %% [markdown]
# # Google Colab Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
PROJECT_PATH = 'Colab Notebooks/Natural Language Processing/AI-detection/'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', PROJECT_PATH)

# %% [markdown]
# # Import tools

# %%
# !pip install ipython-autotime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.0 MB/s eta 0:00:00
# ...

# %%
# %run "{GOOGLE_DRIVE_PATH}/tools.ipynb"
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# time: 16.9 ms (started: 2024-05-08 01:29:53 +00:00)

# %% [markdown]
# # Import data

# %%
with open(f'{GOOGLE_DRIVE_PATH}/source/test_data_with_stopwords.pkl', 'rb') as file:
      loaded_test_data = pickle.load(file)

X_test_with_stopwords = loaded_test_data['X_test']
y_test_with_stopwords = loaded_test_data['y_test']


with open(f'{GOOGLE_DRIVE_PATH}/source/test_data_without_stopwords.pkl', 'rb') as file:
      loaded_test_data = pickle.load(file)

X_test_without_stopwords = loaded_test_data['X_test']
y_test_without_stopwords = loaded_test_data['y_test']


with open(f'{GOOGLE_DRIVE_PATH}/source/test_data_padded.pkl', 'rb') as file:
      loaded_test_data = pickle.load(file)

X_test_padded = loaded_test_data['X_test']
y_test_padded = loaded_test_data['y_test']


with open(f'{GOOGLE_DRIVE_PATH}/source/test_data_padded_pretrained.pkl', 'rb') as file:
      loaded_test_data = pickle.load(file)

X_test_padded_pretrained = loaded_test_data['X_test']
y_test_padded_pretrained = loaded_test_data['y_test']


with open(f'{GOOGLE_DRIVE_PATH}/source/test_data_padded_word2vec.pkl', 'rb') as file:
      loaded_test_data = pickle.load(file)

X_test_padded_word2vec = loaded_test_data['X_test']
y_test_padded_word2vec = loaded_test_data['y_test']
# Out:
# time: 7.13 s (started: 2024-05-08 01:29:53 +00:00)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Unigram

# %%
# Keep stopwords
_evaluate_model('RandomForest_unigram_keep_stopwords.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      5361
#            1       0.94      0.93      0.94      5401
#
#     accuracy                           0.94     10762
#    macro avg       0.94      0.94      0.94     10762
# weighted avg       0.94      0.94      0.94     10762
# time: 3.12 s (started: 2024-05-07 17:30:01 +00:00)

# %%
# Remove stopwords
_evaluate_model('RandomForest_unigram.joblib', X_test_without_stopwords, y_test_without_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5361
#            1       0.95      0.88      0.91      5401
#
#     accuracy                           0.92     10762
#    macro avg       0.92      0.92      0.92     10762
# weighted avg       0.92      0.92      0.92     10762
# time: 2.03 s (started: 2024-05-05 15:52:37 +00:00)

# %% [markdown]
# ### Bigram

# %%
_evaluate_model('RandomForest_bigram.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      5361
#            1       0.96      0.84      0.89      5401
#
#     accuracy                           0.90     10762
#    macro avg       0.90      0.90      0.90     10762
# weighted avg       0.90      0.90      0.90     10762
# time: 9.67 s (started: 2024-05-05 15:52:39 +00:00)

# %% [markdown]
# ### 3 grams

# %%
_evaluate_model('RandomForest_three-gram.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.88      5361
#            1       0.98      0.74      0.84      5401
#
#     accuracy                           0.86     10762
#    macro avg       0.88      0.86      0.86     10762
# weighted avg       0.88      0.86      0.86     10762
# time: 17.3 s (started: 2024-05-05 15:52:49 +00:00)

# %% [markdown]
# ### 4 grams

# %%
_evaluate_model('RandomForest_four-gram.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.99      0.83      5361
#            1       0.99      0.61      0.75      5401
#
#     accuracy                           0.80     10762
#    macro avg       0.85      0.80      0.79     10762
# weighted avg       0.85      0.80      0.79     10762
# time: 20.9 s (started: 2024-05-05 15:53:06 +00:00)

# %% [markdown]
# ### 8 grams

# %%
_evaluate_model('RandomForest_eight-gram.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      1.00      0.72      5361
#            1       1.00      0.24      0.39      5401
#
#     accuracy                           0.62     10762
#    macro avg       0.78      0.62      0.56     10762
# weighted avg       0.78      0.62      0.56     10762
# time: 24.1 s (started: 2024-05-05 15:53:27 +00:00)

# %% [markdown]
# ### The combination of CountVectorizer and TF-IDF

# %%
_evaluate_model('RandomForest_unigram-tfidf.joblib', X_test_with_stopwords, y_test_with_stopwords, 'RandomForest')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      5361
#            1       0.94      0.92      0.93      5401
#
#     accuracy                           0.93     10762
#    macro avg       0.93      0.93      0.93     10762
# weighted avg       0.93      0.93      0.93     10762
# time: 3.38 s (started: 2024-05-05 15:53:51 +00:00)

# %% [markdown]
# # LSTM

# %% [markdown]
# ### LSTM

# %%
_evaluate_model('LSTM.h5', X_test_padded, y_test_padded, 'LSTM')
# Out:
# 337/337 [==============================] - 8s 19ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      5361
#            1       0.98      0.95      0.96      5401
#
#     accuracy                           0.96     10762
#    macro avg       0.96      0.96      0.96     10762
# weighted avg       0.96      0.96      0.96     10762
# time: 15.1 s (started: 2024-05-08 01:30:00 +00:00)

# %% [markdown]
# ### BiLSTM

# %%
_evaluate_model('LSTM-BI.h5', X_test_padded, y_test_padded, 'LSTM')
# Out:
# 337/337 [==============================] - 10s 27ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      5361
#            1       0.98      0.98      0.98      5401
#
#     accuracy                           0.98     10762
#    macro avg       0.98      0.98      0.98     10762
# weighted avg       0.98      0.98      0.98     10762
# time: 15.4 s (started: 2024-05-06 00:29:02 +00:00)

# %% [markdown]
# ### BiLSTM - GloVe

# %%
_evaluate_model('LSTM-BI-glove.h5', X_test_padded_pretrained, y_test_padded_pretrained, 'LSTM')
# Out:
# 337/337 [==============================] - 34s 96ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      5361
#            1       0.99      0.98      0.98      5401
#
#     accuracy                           0.98     10762
#    macro avg       0.98      0.98      0.98     10762
# weighted avg       0.98      0.98      0.98     10762
# time: 38.1 s (started: 2024-05-05 15:50:16 +00:00)

# %% [markdown]
# ### BiLSTM - Word2Vec

# %%
_evaluate_model('LSTM-word2vec.h5', X_test_padded_word2vec, y_test_padded_word2vec, 'LSTM')
# Out:
# 337/337 [==============================] - 31s 89ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85      5401
#            1       0.85      0.84      0.84      5360
#
#     accuracy                           0.84     10761
#    macro avg       0.84      0.84      0.84     10761
# weighted avg       0.84      0.84      0.84     10761
# time: 34.5 s (started: 2024-05-06 00:31:05 +00:00)
